# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.insert(0, parent_dir)

seeds = [42, 69, 420, 1, 3]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Getting the data
#
# As always, let's import our last updated data.

# %%
from utils import load_datasets

gru_data_folder = os.path.join(parent_dir, "3_preprocessing", "output", "gru")
gru_train_set, gru_val_set, gru_test_set = load_datasets(folder=gru_data_folder)

grubert_data_folder = os.path.join(parent_dir, "3_preprocessing", "output", "grubert")
grubert_train_set, grubert_val_set, grubert_test_set = load_datasets(folder=grubert_data_folder)

# %% [markdown]
# # Baseline evaluation

# %%
from metrics import compute_baseline_metrics

f1_not_ironic_random, f1_ironic_random, zero_one_f1_random = compute_baseline_metrics(gru_val_set['iro'], len(gru_val_set), "random", seeds=seeds)

print("The scores are the mean values across all seeds:")
print()
print("f1_not_ironic_random: ", f1_not_ironic_random)
print("f1_ironic_random: ", f1_ironic_random)
print("zero_one_f1_random: ", zero_one_f1_random)
# Out:
# The scores are the mean values across all seeds:
#
# f1_not_ironic_random:  0.6458375794869037
# f1_ironic_random:  0.17243933610161782
# zero_one_f1_random:  0.4091384577942607

# %%
f1_not_ironic_majority, f1_1_ironic_majority, zero_one_f1_majority = compute_baseline_metrics(gru_val_set['iro'], len(gru_val_set), "majority", seeds=seeds)

print("f1_not_ironic_majority:", f1_not_ironic_majority)
print("f1_ironic_majority: ", f1_1_ironic_majority)
print("zero_one_f1_majority: ", zero_one_f1_majority)
# Out:
# f1_not_ironic_majority: 0.9428571428571428
# f1_ironic_majority:  0.0
# zero_one_f1_majority:  0.4714285714285714

# %% [markdown]
# # Gru Evaluation

# %% [markdown]
# ## Validation Set

# %%
from typing import Dict
import torch
import pandas as pd
from tqdm import tqdm
from metrics import DataFactory, Evaluator

results_val_Gru: Dict[int, pd.DataFrame] = {}

for seed in seeds:
    print("Seed", seed)
    parent_dir_weights = os.path.join(parent_dir, f'6_training/weights/{seed}/')
    weights_file_names = [
        "Gru_base_case.pth",
        "Gru_hashtag_segmentation.pth",
        "Gru_pos_tags_enrichment.pth",
        "Gru_hashtag_enrichment.pth",
    ]

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # 1) Create a DataFactory
    data_factory = DataFactory(
        embedding_model_path=os.path.join(parent_dir, "embedding_models/italian_word2vec_100.bin"),
        bert_model_name="m-polignano-uniba/bert_uncased_L-12_H-768_A-12_italian_alb3rt0"
    )

    # 2) Create an Evaluator
    evaluator = Evaluator(
        data_factory=data_factory,
        device=device,
        gru_hidden_size=32,
        num_gru_layers=2,
        gru_dropout=0.2,
        embedding_dim_gru=100,
        batch_size=8,
        max_len=50
    )

    # 3) Run evaluation
    results_df = evaluator.compute_metrics_over_files(
        file_list=weights_file_names,
        threshold_df=gru_val_set,
        eval_df=gru_val_set,
        parent_dir=parent_dir_weights
    )

    results_val_Gru[seed] = results_df
# Out:
# Seed 42
# Evaluating models: 100%|██████████| 4/4 [01:57<00:00, 29.26s/it]
# Seed 69
# Evaluating models: 100%|██████████| 4/4 [01:50<00:00, 27.68s/it]
# Seed 420
# Evaluating models: 100%|██████████| 4/4 [02:02<00:00, 30.58s/it]
# Seed 1
# Evaluating models: 100%|██████████| 4/4 [02:10<00:00, 32.69s/it]
# Seed 3
# Evaluating models: 100%|██████████| 4/4 [02:07<00:00, 31.81s/it]

# %%
results_val_Gru[42]
# Out:
#   ModelClass         Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0        gru             base_case       0.927130   0.392523    0.659827
# 1        gru  hashtag_segmentation       0.924986   0.408889    0.666937
# 2        gru   pos_tags_enrichment       0.900173   0.347170    0.623671
# 3        gru    hashtag_enrichment       0.909710   0.329114    0.619412
#
#    BestThreshold
# 0           0.30
# 1           0.21
# 2           0.17
# 3           0.19

# %%
results_val_Gru[69]
# Out:
#   ModelClass         Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0        gru             base_case       0.913368   0.407843    0.660605
# 1        gru  hashtag_segmentation       0.933407   0.387755    0.660581
# 2        gru   pos_tags_enrichment       0.914124   0.333333    0.623729
# 3        gru    hashtag_enrichment       0.917369   0.328767    0.623068
#
#    BestThreshold
# 0           0.21
# 1           0.26
# 2           0.20
# 3           0.21

# %%
results_val_Gru[420]
# Out:
#   ModelClass         Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0        gru             base_case       0.924719   0.385321    0.655020
# 1        gru  hashtag_segmentation       0.924888   0.373832    0.649360
# 2        gru   pos_tags_enrichment       0.909710   0.329114    0.619412
# 3        gru    hashtag_enrichment       0.912380   0.323144    0.617762
#
#    BestThreshold
# 0           0.28
# 1           0.21
# 2           0.22
# 3           0.23

# %%
results_val_Gru[1]
# Out:
#   ModelClass         Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0        gru             base_case       0.915621   0.393443    0.654532
# 1        gru  hashtag_segmentation       0.927374   0.375000    0.651187
# 2        gru   pos_tags_enrichment       0.909710   0.329114    0.619412
# 3        gru    hashtag_enrichment       0.908884   0.338843    0.623863
#
#    BestThreshold
# 0           0.25
# 1           0.23
# 2           0.22
# 3           0.20

# %%
results_val_Gru[3]
# Out:
#   ModelClass         Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0        gru             base_case       0.918950   0.422764    0.670857
# 1        gru  hashtag_segmentation       0.914481   0.385246    0.649864
# 2        gru   pos_tags_enrichment       0.906178   0.344000    0.625089
# 3        gru    hashtag_enrichment       0.913314   0.343348    0.628331
#
#    BestThreshold
# 0           0.22
# 1           0.18
# 2           0.18
# 3           0.19

# %% [markdown]
# ## Test Set

# %%
from typing import Dict
import torch
import pandas as pd
from tqdm import tqdm
from metrics import DataFactory, Evaluator

results_test_Gru: Dict[int, pd.DataFrame] = {}
seeds = [42, 69, 420, 1, 3]

for seed in seeds:
    print("Seed", seed)
    parent_dir_weights = os.path.join(parent_dir, f'6_training/weights/{seed}/')
    weights_file_names = [
        "Gru_base_case.pth",
        "Gru_hashtag_segmentation.pth",
        "Gru_pos_tags_enrichment.pth",
        "Gru_hashtag_enrichment.pth",
    ]

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # 1) Create a DataFactory
    data_factory = DataFactory(
        embedding_model_path=os.path.join(parent_dir, "embedding_models/italian_word2vec_100.bin"),
        bert_model_name="m-polignano-uniba/bert_uncased_L-12_H-768_A-12_italian_alb3rt0"
    )

    # 2) Create an Evaluator
    evaluator = Evaluator(
        data_factory=data_factory,
        device=device,
        gru_hidden_size=32,
        num_gru_layers=2,
        gru_dropout=0.2,
        embedding_dim_gru=100,
        batch_size=8,
        max_len=50
    )

    # 3) Run evaluation
    results_df = evaluator.compute_metrics_over_files(
        file_list=weights_file_names,
        threshold_df=gru_val_set,
        eval_df=gru_test_set,
        parent_dir=parent_dir_weights
    )

    results_test_Gru[seed] = results_df
# Out:
# Seed 42
# Evaluating models: 100%|██████████| 4/4 [01:50<00:00, 27.53s/it]
# Seed 69
# Evaluating models: 100%|██████████| 4/4 [01:44<00:00, 26.23s/it]
# Seed 420
# Evaluating models: 100%|██████████| 4/4 [01:45<00:00, 26.32s/it]
# Seed 1
# Evaluating models: 100%|██████████| 4/4 [01:43<00:00, 25.88s/it]
# Seed 3
# Evaluating models: 100%|██████████| 4/4 [01:40<00:00, 25.24s/it]

# %%
results_test_Gru[42]
# Out:
#   ModelClass         Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0        gru             base_case       0.924464   0.401786    0.663125
# 1        gru  hashtag_segmentation       0.919318   0.403361    0.661340
# 2        gru   pos_tags_enrichment       0.895505   0.371930    0.633717
# 3        gru    hashtag_enrichment       0.905227   0.357977    0.631602
#
#    BestThreshold
# 0           0.30
# 1           0.21
# 2           0.17
# 3           0.19

# %%
results_test_Gru[69]
# Out:
#   ModelClass         Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0        gru             base_case       0.904429   0.418440    0.661434
# 1        gru  hashtag_segmentation       0.923767   0.364486    0.644126
# 2        gru   pos_tags_enrichment       0.915909   0.378151    0.647030
# 3        gru    hashtag_enrichment       0.918644   0.368421    0.643533
#
#    BestThreshold
# 0           0.21
# 1           0.26
# 2           0.20
# 3           0.21

# %%
results_test_Gru[420]
# Out:
#   ModelClass         Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0        gru             base_case       0.923251   0.398230    0.660740
# 1        gru  hashtag_segmentation       0.918980   0.386266    0.652623
# 2        gru   pos_tags_enrichment       0.913242   0.382114    0.647678
# 3        gru    hashtag_enrichment       0.917847   0.377682    0.647765
#
#    BestThreshold
# 0           0.28
# 1           0.21
# 2           0.22
# 3           0.23

# %%
results_test_Gru[1]
# Out:
#   ModelClass         Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0        gru             base_case       0.914845   0.430769    0.672807
# 1        gru  hashtag_segmentation       0.919618   0.347032    0.633325
# 2        gru   pos_tags_enrichment       0.913242   0.382114    0.647678
# 3        gru    hashtag_enrichment       0.919290   0.438247    0.678769
#
#    BestThreshold
# 0           0.25
# 1           0.23
# 2           0.22
# 3           0.20

# %%
results_test_Gru[3]
# Out:
#   ModelClass         Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0        gru             base_case       0.909302   0.438849    0.674076
# 1        gru  hashtag_segmentation       0.911392   0.407692    0.659542
# 2        gru   pos_tags_enrichment       0.907514   0.402985    0.655250
# 3        gru    hashtag_enrichment       0.911899   0.384000    0.647950
#
#    BestThreshold
# 0           0.22
# 1           0.18
# 2           0.18
# 3           0.19

# %% [markdown]
# ## Display

# %%
from metrics import average_out_scores_for_seeds

average_results_val = average_out_scores_for_seeds(results_val_Gru)

average_results_val
# Out:
#                                 F1_not_ironic           F1_ironic            \
#                                          mean       std      mean       std
# ModelClass Configuration
# gru        base_case                 0.919958  0.005860  0.400379  0.014945
#            hashtag_enrichment        0.912332  0.003358  0.332643  0.008227
#            hashtag_segmentation      0.925027  0.006837  0.386144  0.014111
#            pos_tags_enrichment       0.907979  0.005195  0.336546  0.008503
#
#                                 F1_avg_0_1           BestThreshold
#                                       mean       std          mean       std
# ModelClass Configuration
# gru        base_case              0.660168  0.006573         0.252  0.038341
#            hashtag_enrichment     0.622487  0.004128         0.204  0.016733
#            hashtag_segmentation   0.655586  0.007821         0.218  0.029496
#            pos_tags_enrichment    0.622263  0.002663         0.198  0.022804

# %%
average_results_test = average_out_scores_for_seeds(results_test_Gru)

average_results_test
# Out:
#                                 F1_not_ironic           F1_ironic            \
#                                          mean       std      mean       std
# ModelClass Configuration
# gru        base_case                 0.915258  0.008683  0.417615  0.017684
#            hashtag_enrichment        0.914581  0.006001  0.385265  0.031203
#            hashtag_segmentation      0.918615  0.004482  0.381768  0.025806
#            pos_tags_enrichment       0.909083  0.008186  0.383459  0.011683
#
#                                 F1_avg_0_1           BestThreshold
#                                       mean       std          mean       std
# ModelClass Configuration
# gru        base_case              0.666436  0.006469         0.252  0.038341
#            hashtag_enrichment     0.649923  0.017444         0.204  0.016733
#            hashtag_segmentation   0.650191  0.011607         0.218  0.029496
#            pos_tags_enrichment    0.646271  0.007790         0.198  0.022804

# %% [markdown]
# # GruBERT Evaluation

# %% [markdown]
# ## Validation Set

# %%
from typing import Dict
import torch
import pandas as pd
from tqdm import tqdm
from metrics import DataFactory, Evaluator

results_val_GruBERT: Dict[int, pd.DataFrame] = {}
seeds = [42, 69, 420, 1, 3]

for seed in seeds:
    print("Seed", seed)
    parent_dir_weights = os.path.join(parent_dir, f'6_training/weights/{seed}/')
    weights_file_names = [
        "GruBERT_base_case.pth",
        "GruBERT_pos_tags_enrichment.pth",
        "GruBERT_hashtag_enrichment.pth",
    ]

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # 1) Create a DataFactory
    data_factory = DataFactory(
        embedding_model_path=os.path.join(parent_dir, "embedding_models/italian_word2vec_100.bin"),
        bert_model_name="m-polignano-uniba/bert_uncased_L-12_H-768_A-12_italian_alb3rt0"
    )

    # 2) Create an Evaluator
    evaluator = Evaluator(
        data_factory=data_factory,
        device=device,
        gru_hidden_size=32,
        num_gru_layers=2,
        gru_dropout=0.2,
        embedding_dim_gru=100,
        batch_size=8,
        max_len=50
    )

    # 3) Run evaluation
    results_df = evaluator.compute_metrics_over_files(
        file_list=weights_file_names,
        threshold_df=gru_val_set,
        eval_df=gru_val_set,
        parent_dir=parent_dir_weights
    )

    results_val_GruBERT[seed] = results_df
# Out:
# Seed 42
# Evaluating models:   0%|          | 0/3 [00:00<?, ?it/s]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\transformers\models\bert\modeling_bert.py:435: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# Evaluating models:  33%|███▎      | 1/3 [00:12<00:24, 12.12s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  67%|██████▋   | 2/3 [00:26<00:13, 13.43s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models: 100%|██████████| 3/3 [00:40<00:00, 13.66s/it]
# Seed 69
# Evaluating models:   0%|          | 0/3 [00:00<?, ?it/s]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  33%|███▎      | 1/3 [00:07<00:15,  7.74s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  67%|██████▋   | 2/3 [00:22<00:12, 12.09s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models: 100%|██████████| 3/3 [00:37<00:00, 12.65s/it]
# Seed 420
# Evaluating models:   0%|          | 0/3 [00:00<?, ?it/s]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  33%|███▎      | 1/3 [00:08<00:16,  8.24s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  67%|██████▋   | 2/3 [00:24<00:12, 12.75s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models: 100%|██████████| 3/3 [00:40<00:00, 13.45s/it]
# Seed 1
# Evaluating models:   0%|          | 0/3 [00:00<?, ?it/s]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  33%|███▎      | 1/3 [00:08<00:16,  8.31s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  67%|██████▋   | 2/3 [00:25<00:13, 13.25s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models: 100%|██████████| 3/3 [00:41<00:00, 13.73s/it]
# Seed 3
# Evaluating models:   0%|          | 0/3 [00:00<?, ?it/s]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  33%|███▎      | 1/3 [00:08<00:16,  8.22s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  67%|██████▋   | 2/3 [00:24<00:12, 12.90s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models: 100%|██████████| 3/3 [00:40<00:00, 13.39s/it]

# %%
results_val_GruBERT[42]
# Out:
#   ModelClass        Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0    grubert            base_case       0.917473   0.398340    0.657907
# 1    grubert  pos_tags_enrichment       0.904378   0.366412    0.635395
# 2    grubert   hashtag_enrichment       0.896793   0.374558    0.635676
#
#    BestThreshold
# 0           0.20
# 1           0.19
# 2           0.17

# %%
results_val_GruBERT[69]
# Out:
#   ModelClass        Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0    grubert            base_case       0.909925   0.384314    0.647120
# 1    grubert  pos_tags_enrichment       0.918402   0.343891    0.631147
# 2    grubert   hashtag_enrichment       0.910857   0.370968    0.640912
#
#    BestThreshold
# 0           0.18
# 1           0.25
# 2           0.19

# %%
results_val_GruBERT[420]
# Out:
#   ModelClass        Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0    grubert            base_case       0.930901   0.338624    0.634763
# 1    grubert  pos_tags_enrichment       0.911798   0.388889    0.650344
# 2    grubert   hashtag_enrichment       0.928412   0.390476    0.659444
#
#    BestThreshold
# 0           0.22
# 1           0.19
# 2           0.26

# %%
results_val_GruBERT[1]
# Out:
#   ModelClass        Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0    grubert            base_case       0.927536   0.362745    0.645141
# 1    grubert  pos_tags_enrichment       0.911798   0.388889    0.650344
# 2    grubert   hashtag_enrichment       0.922292   0.417021    0.669656
#
#    BestThreshold
# 0           0.26
# 1           0.19
# 2           0.23

# %%
results_val_GruBERT[3]
# Out:
#   ModelClass        Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0    grubert            base_case       0.918919   0.351351    0.635135
# 1    grubert  pos_tags_enrichment       0.932157   0.335135    0.633646
# 2    grubert   hashtag_enrichment       0.910745   0.343096    0.626920
#
#    BestThreshold
# 0           0.20
# 1           0.25
# 2           0.19

# %% [markdown]
# ## Test Set

# %%
from typing import Dict
import torch
import pandas as pd
from tqdm import tqdm
from metrics import DataFactory, Evaluator

results_test_GruBERT: Dict[int, pd.DataFrame] = {}
seeds = [42, 69, 420, 1, 3]

for seed in seeds:
    print("Seed", seed)
    parent_dir_weights = os.path.join(parent_dir, f'6_training/weights/{seed}/')
    weights_file_names = [
        "GruBERT_base_case.pth",
        "GruBERT_pos_tags_enrichment.pth",
        "GruBERT_hashtag_enrichment.pth",
    ]

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # 1) Create a DataFactory
    data_factory = DataFactory(
        embedding_model_path=os.path.join(parent_dir, "embedding_models/italian_word2vec_100.bin"),
        bert_model_name="m-polignano-uniba/bert_uncased_L-12_H-768_A-12_italian_alb3rt0"
    )

    # 2) Create an Evaluator
    evaluator = Evaluator(
        data_factory=data_factory,
        device=device,
        gru_hidden_size=32,
        num_gru_layers=2,
        gru_dropout=0.2,
        embedding_dim_gru=100,
        batch_size=8,
        max_len=50
    )

    # 3) Run evaluation
    results_df = evaluator.compute_metrics_over_files(
        file_list=weights_file_names,
        threshold_df=gru_val_set,
        eval_df=gru_test_set,
        parent_dir=parent_dir_weights
    )

    results_test_GruBERT[seed] = results_df
# Out:
# Seed 42
# Evaluating models:   0%|          | 0/3 [00:00<?, ?it/s]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  33%|███▎      | 1/3 [00:08<00:17,  8.75s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  67%|██████▋   | 2/3 [00:24<00:12, 12.94s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models: 100%|██████████| 3/3 [00:41<00:00, 13.74s/it]
# Seed 69
# Evaluating models:   0%|          | 0/3 [00:00<?, ?it/s]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  33%|███▎      | 1/3 [00:08<00:16,  8.24s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  67%|██████▋   | 2/3 [00:23<00:12, 12.50s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models: 100%|██████████| 3/3 [00:38<00:00, 12.97s/it]
# Seed 420
# Evaluating models:   0%|          | 0/3 [00:00<?, ?it/s]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  33%|███▎      | 1/3 [00:08<00:16,  8.30s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  67%|██████▋   | 2/3 [00:24<00:12, 12.72s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models: 100%|██████████| 3/3 [00:39<00:00, 13.09s/it]
# Seed 1
# Evaluating models:   0%|          | 0/3 [00:00<?, ?it/s]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  33%|███▎      | 1/3 [00:08<00:16,  8.04s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  67%|██████▋   | 2/3 [00:22<00:12, 12.07s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models: 100%|██████████| 3/3 [00:37<00:00, 12.64s/it]
# Seed 3
# Evaluating models:   0%|          | 0/3 [00:00<?, ?it/s]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  33%|███▎      | 1/3 [00:08<00:16,  8.15s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models:  67%|██████▋   | 2/3 [00:23<00:12, 12.23s/it]c:\Users\marcy\miniconda3\envs\MyTorch\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Evaluating models: 100%|██████████| 3/3 [00:38<00:00, 12.87s/it]

# %%
results_test_GruBERT[42]
# Out:
#   ModelClass        Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0    grubert            base_case       0.913422   0.462094    0.687758
# 1    grubert  pos_tags_enrichment       0.906854   0.453608    0.680231
# 2    grubert   hashtag_enrichment       0.901125   0.459547    0.680336
#
#    BestThreshold
# 0           0.20
# 1           0.19
# 2           0.17

# %%
results_test_GruBERT[69]
# Out:
#   ModelClass        Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0    grubert            base_case       0.904061   0.454849    0.679455
# 1    grubert  pos_tags_enrichment       0.924915   0.450000    0.687457
# 2    grubert   hashtag_enrichment       0.906141   0.404412    0.655277
#
#    BestThreshold
# 0           0.18
# 1           0.25
# 2           0.19

# %%
results_test_GruBERT[420]
# Out:
#   ModelClass        Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0    grubert            base_case       0.926009   0.383178    0.654593
# 1    grubert  pos_tags_enrichment       0.897076   0.388889    0.642982
# 2    grubert   hashtag_enrichment       0.921759   0.445344    0.683552
#
#    BestThreshold
# 0           0.22
# 1           0.19
# 2           0.26

# %%
results_test_GruBERT[1]
# Out:
#   ModelClass        Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0    grubert            base_case       0.925000   0.445378    0.685189
# 1    grubert  pos_tags_enrichment       0.897076   0.388889    0.642982
# 2    grubert   hashtag_enrichment       0.915371   0.436782    0.676076
#
#    BestThreshold
# 0           0.26
# 1           0.19
# 2           0.23

# %%
results_test_GruBERT[3]
# Out:
#   ModelClass        Configuration  F1_not_ironic  F1_ironic  F1_avg_0_1  \
# 0    grubert            base_case       0.910560   0.415094    0.662827
# 1    grubert  pos_tags_enrichment       0.927731   0.394366    0.661049
# 2    grubert   hashtag_enrichment       0.914022   0.437736    0.675879
#
#    BestThreshold
# 0           0.20
# 1           0.25
# 2           0.19

# %% [markdown]
# ## Display

# %%
from metrics import average_out_scores_for_seeds

average_results_val = average_out_scores_for_seeds(results_val_GruBERT)

average_results_val
# Out:
#                                F1_not_ironic           F1_ironic            \
#                                         mean       std      mean       std
# ModelClass Configuration
# grubert    base_case                0.920951  0.008369  0.367075  0.024239
#            hashtag_enrichment       0.913820  0.012174  0.379224  0.027159
#            pos_tags_enrichment      0.915707  0.010449  0.364643  0.024901
#
#                                F1_avg_0_1           BestThreshold
#                                      mean       std          mean       std
# ModelClass Configuration
# grubert    base_case             0.644013  0.009596         0.212  0.030332
#            hashtag_enrichment    0.646522  0.017575         0.208  0.036332
#            pos_tags_enrichment   0.640175  0.009405         0.214  0.032863

# %%
average_results_test = average_out_scores_for_seeds(results_test_GruBERT)

average_results_test
# Out:
#                                F1_not_ironic           F1_ironic            \
#                                         mean       std      mean       std
# ModelClass Configuration
# grubert    base_case                0.915810  0.009484  0.432119  0.032696
#            hashtag_enrichment       0.911684  0.008105  0.436764  0.020250
#            pos_tags_enrichment      0.910730  0.014817  0.415150  0.033559
#
#                                F1_avg_0_1           BestThreshold
#                                      mean       std          mean       std
# ModelClass Configuration
# grubert    base_case             0.673965  0.014540         0.212  0.030332
#            hashtag_enrichment    0.674224  0.011063         0.208  0.036332
#            pos_tags_enrichment   0.662940  0.020617         0.214  0.032863
